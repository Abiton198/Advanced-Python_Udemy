# %%
import matplotlib.pyplot as graph
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import pyplot as plt

# %%
a = np.arange(0,210,30)
x = np.cos(a)
y = np.sin(a)
graph.plot(a,x, color='blue')
graph.plot(a,y, color='red')
graph.show()

# %%
a = np.arange(0,10,1) #gives a range of numbers 0-10, skip with 1
x =np.sqrt(a)  #exponentials
y = np.exp(x)
graph.plot(a,x, color='blue')
